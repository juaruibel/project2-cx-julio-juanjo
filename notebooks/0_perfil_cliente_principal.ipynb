# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
from pathlib import Path

# Sube de notebooks/ a la raíz del repo

sys.path.append(str(Path.cwd().parent))

# Importamos funciones

import src.functions as fc

# %matplotlib inline 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_demo.txt")
df2_1 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_1.txt")
df2_2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_2.txt")
df3 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_experiment_clients.txt")

# %% [markdown]
# Unimos los dos df del df 2 (2_1 y 2_2)

# %%
df2_1.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
df2_1.dtypes
# Out:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
fc.informe(df2_1)
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343141 entries, 0 to 343140
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     343141 non-null  int64
#  1   visitor_id    343141 non-null  object
#  2   visit_id      343141 non-null  object
#  3   process_step  343141 non-null  object
#  4   date_time     343141 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 13.1+ MB
# None
# Descripción estadística:
#           client_id
# count  3.431410e+05
# mean   4.996097e+06
# std    2.875839e+06
# min    1.690000e+02
# 25%    2.506067e+06
# 50%    5.007915e+06
# 75%    7.468519e+06
# max    9.999839e+06
# Valores nulos:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64
# Tipos de datos:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# ...

# %%
fc.datos(df2_1)
# Out:
# datos nulos
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64
# datos totales
# client_id       343141
# visitor_id      343141
# visit_id        343141
# process_step    343141
# date_time       343141
# dtype: int64
# porcentaje de nulos
# client_id       0.0
# visitor_id      0.0
# visit_id        0.0
# process_step    0.0
# date_time       0.0
# dtype: float64
# datos duplicados
# 2095

# %%
df2_2.dtypes
# Out:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
fc.informe(df2_2)
# Out:
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412264 entries, 0 to 412263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     412264 non-null  int64
#  1   visitor_id    412264 non-null  object
#  2   visit_id      412264 non-null  object
#  3   process_step  412264 non-null  object
#  4   date_time     412264 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 15.7+ MB
# None
# Descripción estadística:
#           client_id
# count  4.122640e+05
# mean   5.028227e+06
# std    2.881828e+06
# min    3.360000e+02
# 25%    2.533952e+06
# 50%    5.056314e+06
# 75%    7.516792e+06
# max    9.999875e+06
# Valores nulos:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64
# Tipos de datos:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# ...

# %%
fc.datos(df2_2)
# Out:
# datos nulos
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64
# datos totales
# client_id       412264
# visitor_id      412264
# visit_id        412264
# process_step    412264
# date_time       412264
# dtype: int64
# porcentaje de nulos
# client_id       0.0
# visitor_id      0.0
# visit_id        0.0
# process_step    0.0
# date_time       0.0
# dtype: float64
# datos duplicados
# 8669

# %% [markdown]
# ver patrones de comportamiento de los pasos que dan, si están en test o en control, etc...

# %% [markdown]
# # EDA

# %%
df1.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
filas_con_nulos = df1[df1.isna().any(axis=1)]
filas_con_nulos.head()
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 4164     7402828             NaN               NaN       NaN   NaN        NaN
# 8316      355337             NaN               NaN       NaN   NaN        NaN
# 8677     8412164             NaN               NaN       NaN   NaN        NaN
# 9583     4666211             8.0             106.0       NaN     F        2.0
# 13444    2222915             NaN               NaN       NaN   NaN        NaN
#
#             bal  calls_6_mnth  logons_6_mnth
# 4164        NaN           NaN            NaN
# 8316        NaN           NaN            NaN
# 8677        NaN           NaN            NaN
# 9583   42550.55           4.0            7.0
# 13444       NaN           NaN            NaN

# %%
# Eliminamos NaN

df1 = fc.eliminar_na(df1)

# %%
# Comprobación: mantenemos clnt_age porque el resto de valores está definido

df1.isna().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            1
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# dtype: int64

# %%
# Definimos características del cliente principal
# Empezamos por la moda de llamadas
# Moda de logins
# Categorizamos clnt_age discretizándolo
# Categorizamos clnt_tenure_yr discretizándolo
# Filtramos por percentil 25 en balance, definiendo así: high_value_client

high_value_client = fc.cliente_principal(df1)
high_value_client.head()
# Out:
# /Users/juaruibel/Projects/BOOTCAMP/Unit 05 - EDA and Inferential Stats/project2-cx-julio-juanjo/src/functions.py:304: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/juaruibel/Projects/BOOTCAMP/Unit 05 - EDA and Inferential Stats/project2-cx-julio-juanjo/src/functions.py:309: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/juaruibel/Projects/BOOTCAMP/Unit 05 - EDA and Inferential Stats/project2-cx-julio-juanjo/src/functions.py:312: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## Visualizaciones

# %%
fc.visual_pie_chart_age(high_value_client)
# Out:
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %%
fc.visual_pie_chart_tenure_yr(high_value_client)
# Out:
# (<Figure size 600x600 with 1 Axes>, <Axes: >)

# %% [markdown]
# # INSIGHTS
#
# Identificamos el perfil del cliente principal utilizando la moda de las variable de logins en 6 meses, ya que esta representa el tipo de usuario más frecuente que utiliza el proceso en línea. En concreto, se optó por la moda debido a que su valor corresponde al valor máximo en la variable (9). Se realizó el mismo proceso con la variable de llamadas en 6 meses. El valor que representa la moda es el valor máximo de la variable (6).
#
# Adicionalmente, se tuvo en cuenta la variable balance con el objetivo de contextualizar la relevancia económica de este perfil de cliente. En este caso se tuvo en cuenta el 75% de cifras superiores de balance.
#
# Para estructurar el análisis posterior, los clientes fueron agrupados en categorías demográficas y de comportamiento, tales como rangos de edad y tipología de cliente (por antigüedad en la plataforma).

# %% [markdown]
# ## EXPORTACIONES PARA TABLEAU

# %%
fc.save_data_clean_excel(high_value_client, "high_value_client")
fc.save_data_clean_excel(df1, "Perfil demográfico")
# Out:
# Guardado: /Users/juaruibel/Projects/BOOTCAMP/Unit 05 - EDA and Inferential Stats/project2-cx-julio-juanjo/data/cleaned/20260218_1112_high_value_client.xlsx
# Guardado: /Users/juaruibel/Projects/BOOTCAMP/Unit 05 - EDA and Inferential Stats/project2-cx-julio-juanjo/data/cleaned/20260218_1112_Perfil demográfico.xlsx
# 'ok'
